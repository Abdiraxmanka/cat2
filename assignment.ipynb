# %%
# EXPLORATORY DATA ANALYSIS

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset
myData = pd.read_csv('NSE_data_all_stocks_2013.csv')

# %%
# displaying the first 5 items
myData.head()
# Out:
#        DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  2-Jan-13  EGAD              Eaagads Ltd     8.2       14      25       25
# 1  2-Jan-13  KUKZ               Kakuzi Plc     300    423.5    67.5     67.5
# 2  2-Jan-13  KAPC  Kapchorua Tea Kenya Plc      59       95     118      118
# 3  2-Jan-13  LIMT           Limuru Tea Plc     385      475     430      430
# 4  2-Jan-13  SASN               Sasini Plc    14.8     19.6    11.7    12.05
#
#   Day Price Previous Change Change%  Volume Adjust
# 0        25       25      -       -       -      -
# 1      67.5       72   -4.5   6.25%     300      -
# 2       118      118      -       -       -     59
# 3       430      430      -       -       -    215
# 4      11.9     11.7    0.2   1.71%  14,500      -

# %%
# check for missing values
myData.isnull().sum()
# Out:
# DATE         0
# CODE         0
# NAME         0
# 12m Low      0
# 12m High     0
# Day Low      0
# Day High     0
# Day Price    0
# Previous     0
# Change       0
# Change%      0
# Volume       0
# Adjust       0
# dtype: int64

# %%
# checking Data types
myData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14889 entries, 0 to 14888
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       14889 non-null  object
#  1   CODE       14889 non-null  object
#  2   NAME       14889 non-null  object
#  3   12m Low    14889 non-null  object
#  4   12m High   14889 non-null  object
#  5   Day Low    14889 non-null  object
#  6   Day High   14889 non-null  object
#  7   Day Price  14889 non-null  object
#  8   Previous   14889 non-null  object
#  9   Change     14889 non-null  object
#  10  Change%    14889 non-null  object
#  11  Volume     14889 non-null  object
#  12  Adjust     14889 non-null  object
# dtypes: object(13)
# memory usage: 1.5+ MB

# %%
# Checking for wrong entries like symbols -,?,#,*,etc.
for col in myData.columns:
    print('{} : {}'.format(col,myData[col].unique()))
# Out:
# DATE : ['2-Jan-13' '3-Jan-13' '4-Jan-13' '7-Jan-13' '8-Jan-13' '9-Jan-13'
#  '10-Jan-13' '11-Jan-13' '14-Jan-13' '15-Jan-13' '16-Jan-13' '17-Jan-13'
#  '18-Jan-13' '21-Jan-13' '22-Jan-13' '23-Jan-13' '24-Jan-13' '25-Jan-13'
#  '28-Jan-13' '29-Jan-13' '30-Jan-13' '31-Jan-13' '1-Feb-13' '4-Feb-13'
#  '5-Feb-13' '6-Feb-13' '7-Feb-13' '8-Feb-13' '11-Feb-13' '12-Feb-13'
#  '13-Feb-13' '14-Feb-13' '15-Feb-13' '18-Feb-13' '19-Feb-13' '20-Feb-13'
#  '21-Feb-13' '22-Feb-13' '25-Feb-13' '26-Feb-13' '27-Feb-13' '28-Feb-13'
#  '1-Mar-13' '5-Mar-13' '6-Mar-13' '7-Mar-13' '8-Mar-13' '11-Mar-13'
#  '12-Mar-13' '13-Mar-13' '14-Mar-13' '15-Mar-13' '18-Mar-13' '19-Mar-13'
#  '20-Mar-13' '21-Mar-13' '22-Mar-13' '25-Mar-13' '26-Mar-13' '27-Mar-13'
#  '28-Mar-13' '2-Apr-13' '3-Apr-13' '4-Apr-13' '5-Apr-13' '8-Apr-13'
#  '10-Apr-13' '11-Apr-13' '12-Apr-13' '15-Apr-13' '16-Apr-13' '17-Apr-13'
#  '18-Apr-13' '19-Apr-13' '22-Apr-13' '23-Apr-13' '24-Apr-13' '25-Apr-13'
# ...

# %%
# Visualizing missing values
sns.heatmap(myData.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.histplot(myData.Change,bins=10)
plt.show()

# %%
# How volume affects price?
plt.figure(figsize=(10,10))
plt.scatter(x='Volume',y='Day Price',data=myData)
plt.xlabel('Volume')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
# Relationship between Day Price and Volume
sns.boxplot(x='Day Price',y='Volume',data=auto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 # Relationship between Day Price and Volume
# ----> 2 sns.boxplot(x='Day Price',y='Volume',data=auto)
#
# NameError: name 'auto' is not defined
